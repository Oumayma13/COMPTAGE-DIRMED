# %%
#Charger les biblio
import numpy as np
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
import numpy as np
import string
from subprocess import check_output
import seaborn as sns
from pylab import *
# %matplotlib inline
sns.set()

# %%
# table isidor
df = pd.read_csv("table3.csv",header=None, sep = ';')

# %%
df.head()
# Out:
#          0
# 0  MM713.I
# 1  MM713.J
# 2  MM713.N
# 3  MM713.O
# 4      M7P

# %%
# table 6min contient la moyenne de Q et vitesse de chaque station
df1 = pd.read_csv("tab_a16.csv", sep = ';')

# %%
# renommer la colonne 
df.columns = ['Code']

# %%
df1.head()
# Out:
#              Q    Vitesse Code
# 0  1246.477227  89.581426  M1A
# 1  1519.982893  90.312153  M1B
# 2  2676.277050  91.922462  M1C
# 3  2585.280382  94.395023  M1D
# 4     0.000000   0.000000  M1E

# %%
# L'intersection 
inter = pd.merge(df, df1, on='Code')

# %%
#puis l'union
result4 = pd.merge(df, inter, how = 'outer')

# %%
result4
# Out:
#         Code            Q    Vitesse
# 0    MM713.I          NaN        NaN
# 1    MM713.J          NaN        NaN
# 2    MM713.N          NaN        NaN
# 3    MM713.O          NaN        NaN
# 4        M7P   810.021783  37.235608
# 5        M7Q   618.048011  28.069571
# 6    MM713.R          NaN        NaN
# 7        M7S  2010.815070  97.251389
# 8        M7T  1537.898866  86.717715
# 9    MM713.U          NaN        NaN
# 10       M7V     0.000000   0.000000
# 11       M8A  2369.630140  70.733941
# 12       M8B  1436.970660  57.754168
# 13       M8C     0.000000   0.000000
# 14       m8D   622.982214  23.016007
# 15       M8D  2049.324517  65.356968
# 16       M8E  3058.367637  79.181374
# 17       M8F  1876.569015  59.858858
# 18       M8G  2754.174039  88.261836
# 19       M8H   877.390976  38.556790
# 20       M8I  2546.943765  81.535008
# 21       M8J   547.131585  18.980440
# 22       M8K   840.366081  67.990665
# 23       M8N  1423.663481  69.034008
# ...

# %%
len(result4) == len(df)
# Out:
# True

# %%
# Exporter la table
result4.to_csv('inter.csv', index = False, encoding = 'utf-8')
